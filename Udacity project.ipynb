# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_seattle = pd.read_csv("seattle/listings.csv")
df_boston = pd.read_csv("boston/listings.csv")

# %%
df_seattle.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
df_boston.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# ...

# %% [markdown]
# #part 1:
#  - whats the mean price for each price for each proparty type in seattle 'vs' boston?
#  - whats the mean rating for each property type in seattle "vs" boston?

# %%
df_seattle.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
# ...

# %%
interested_colmns = ['id','property_type','price','review_scores_rating']
df_seattle = df_seattle.loc[:,interested_colmns]
df_boston = df_boston.loc [:,interested_colmns]

# %%
df_seattle.shape
# Out:
# (3818, 4)

# %%
df_boston.shape
# Out:
# (3585, 4)

# %%
df_boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585 entries, 0 to 3584
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    3585 non-null   int64
#  1   property_type         3582 non-null   object
#  2   price                 3585 non-null   object
#  3   review_scores_rating  2772 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 112.2+ KB

# %%
df_seattle.sample(5)
# Out:
#            id property_type    price  review_scores_rating
# 1990  7151107         House  $299.00                 100.0
# 3577  6066570         House  $545.00                 100.0
# 298   7922373         House   $99.00                 100.0
# 73    1148517         House  $145.00                  97.0
# 1909  4121334         House  $110.00                  98.0

# %%
df_seattle['property_type'].unique()
# Out:
# array(['Apartment', 'House', 'Cabin', 'Condominium', 'Camper/RV',
#        'Bungalow', 'Townhouse', 'Loft', 'Boat', 'Bed & Breakfast',
#        'Other', 'Dorm', 'Treehouse', 'Yurt', 'Chalet', 'Tent', nan],
#       dtype=object)

# %% [markdown]
# ## clean
# - extart number from price column and convert it to float
# - replace none values with 'other' in "propert_type"column
# - replace none values with 0 in 'review_scores_rating'column

# %%
df_seattle["price"] = df_seattle["price"].str.extract("(\d+\.\d+)").astype(float)
df_boston["price"] = df_boston["price"].str.extract("(\d+\.\d+)").astype(float)

# %%
R = df_seattle['property_type'].isnull()
df_seattle.loc[R,'property_type'] = "Other"
R = df_boston['property_type'].isnull()
df_boston.loc[R,'property_type'] = "Other"

# %%
R = df_seattle["review_scores_rating"].isnull()
df_seattle.loc[R,"review_scores_rating"] = 0
R = df_boston["review_scores_rating"].isnull()
df_boston.loc[R, "review_scores_rating"] = 0

# %%
df_seattle.isnull().sum()
# Out:
# id                      0
# property_type           0
# price                   0
# review_scores_rating    0
# dtype: int64

# %%
 df_boston.isnull().sum()
# Out:
# id                      0
# property_type           0
# price                   0
# review_scores_rating    0
# dtype: int64

# %%
df_seattle.sample(5)
# Out:
#            id property_type  price  review_scores_rating
# 1095  6005443     Apartment  129.0                 100.0
# 2192  7745016         House   50.0                 100.0
# 2039   370361         House   85.0                  98.0
# 3608  3773784     Apartment  115.0                  84.0
# 1329  2110357     Apartment   99.0                  97.0

# %%
df_boston.sample(5)
# Out:
#             id property_type  price  review_scores_rating
# 3058   4435883     Apartment  175.0                 100.0
# 1410  10264774     Apartment  299.0                  86.0
# 3439   8758450     Apartment   85.0                 100.0
# 205   10627514         House   70.0                  90.0
# 481   12359031     Apartment  319.0                   0.0

# %%
df_seattle = df_seattle.groupby("property_type",as_index=False).agg({
    "price":"mean","review_scores_rating":"mean",
    "id":"count"}) 
df_seattle.columns =["property_type" , "mean_price" ,"mean_rating","units_count"]

df_seattle
# Out:
#       property_type  mean_price  mean_rating  units_count
# 0         Apartment  122.932670    78.571429         1708
# 1   Bed & Breakfast  112.054054    67.270270           37
# 2              Boat  282.375000    59.750000            8
# 3          Bungalow  115.615385    67.615385           13
# 4             Cabin  104.666667    96.238095           21
# 5         Camper/RV  120.461538    73.615385           13
# 6            Chalet   98.500000    83.500000            2
# 7       Condominium  151.109890    72.274725           91
# 8              Dorm   39.500000    90.000000            2
# 9             House  131.774380    79.894403         1733
# 10             Loft  135.700000    78.750000           40
# 11            Other   95.782609    79.521739           23
# 12             Tent   54.000000    75.600000            5
# 13        Townhouse  129.457627    65.508475          118
# 14        Treehouse  101.000000    64.000000            3
# ...

# %%
df_boston = df_boston.groupby("property_type",as_index=False).agg({
    "price":"mean","review_scores_rating":"mean",
    "id":"count"}) 
df_boston.columns =["property_type" , "mean_price" ,"mean_rating","units_count"]

df_boston
# Out:
#       property_type  mean_price  mean_rating  units_count
# 0         Apartment  176.223966    69.371363         2612
# 1   Bed & Breakfast  129.365854    67.170732           41
# 2              Boat  268.833333    83.833333           12
# 3         Camper/RV   60.000000     0.000000            1
# 4       Condominium  190.246753    72.372294          231
# 5              Dorm   62.500000    86.500000            2
# 6      Entire Floor  122.000000    25.000000            4
# 7        Guesthouse  289.000000   100.000000            1
# 8             House  128.040925    78.587189          562
# 9              Loft  185.410256    79.025641           39
# 10            Other  220.650000    46.900000           20
# 11        Townhouse  149.037037    80.722222           54
# 12            Villa  189.500000    33.166667            6

# %%
df_merge = df_seattle.merge(df_boston, on="property_type", suffixes=("_seattle","_boston"))
df_merge
# Out:
#      property_type  mean_price_seattle  mean_rating_seattle  \
# 0        Apartment          122.932670            78.571429
# 1  Bed & Breakfast          112.054054            67.270270
# 2             Boat          282.375000            59.750000
# 3        Camper/RV          120.461538            73.615385
# 4      Condominium          151.109890            72.274725
# 5             Dorm           39.500000            90.000000
# 6            House          131.774380            79.894403
# 7             Loft          135.700000            78.750000
# 8            Other           95.782609            79.521739
# 9        Townhouse          129.457627            65.508475
#
#    units_count_seattle  mean_price_boston  mean_rating_boston  \
# 0                 1708         176.223966           69.371363
# 1                   37         129.365854           67.170732
# 2                    8         268.833333           83.833333
# ...

# %%
x = np.arange(df_merge.shape[0])
width = 0.35
fig, axs = plt.subplots(1, 2, figsize=(16,6) )
rectle1 = axs[0].bar(x - width/2, df_merge ["mean_price_seattle"], width, label="seattle")
rectle2 = axs[0].bar(x + width/2, df_merge ["mean_price_boston"], width, label="boston")

axs[0].set_ylabel("mean prices")
axs[0].set_title("mean prices seattle vs boston")
axs[0].set_xticks(x)
axs[0].set_xticklabels(df_merge["property_type"],rotation=90)

rectle1 = axs[1].bar(x - width/2, df_merge ["mean_rating_seattle"], width, label="seattle")
rectle2 = axs[1].bar(x + width/2, df_merge ["mean_rating_boston"], width, label="boston")

axs[1].set_ylabel("mean rtind")
axs[1].set_title("mean raiting seattle vs boston")
axs[1].set_xticks(x)
axs[1].set_xticklabels(df_merge["property_type"],rotation=90)



handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper left")
fig.tight_layout()

# %% [raw]
# #part 2
# -
# how can we predict price?

# %%
df_seattle =pd.read_csv("seattle/listings.csv")

# %% [markdown]
# df_seattle.columns

# %%
interest_columns = ["host_response_time",'host_acceptance_rate', 'host_is_superhost' , 'host_has_profile_pic',
   'host_identity_verified', 'neighbourhood_cleansed',  'property_type', 'room_type' , 'accommodates','bathrooms',    
    'bedrooms',"beds","price","number_of_reviews", "review_scores_rating"]

# %%
df_seattle = df_seattle.loc [:,interest_columns ]
df_seattle
# Out:
#       host_response_time host_acceptance_rate host_is_superhost  \
# 0     within a few hours                 100%                 f
# 1         within an hour                 100%                 t
# 2     within a few hours                 100%                 f
# 3                    NaN                  NaN                 f
# 4         within an hour                  NaN                 f
# ...                  ...                  ...               ...
# 3813  within a few hours                 100%                 f
# 3814      within an hour                 100%                 f
# 3815                 NaN                  NaN                 f
# 3816      within an hour                  NaN                 f
# 3817        within a day                  NaN                 f
#
#      host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 0                       t                      t        West Queen Anne
# ...

# %%
df_seattle.isnull().sum()
# Out:
# host_response_time        523
# host_acceptance_rate      773
# host_is_superhost           2
# host_has_profile_pic        2
# host_identity_verified      2
# neighbourhood_cleansed      0
# property_type               1
# room_type                   0
# accommodates                0
# bathrooms                  16
# bedrooms                    6
# beds                        1
# price                       0
# number_of_reviews           0
# review_scores_rating      647
# dtype: int64

# %%
df_seattle["host_response_time"].unique()
# Out:
# array(['within a few hours', 'within an hour', nan, 'within a day',
#        'a few days or more'], dtype=object)

# %%
R = df_seattle["host_response_time"].isnull()
df_seattle.loc[R,"host_response_time"] = "within an hour"

df_seattle["host_acceptance_rate"] = df_seattle["host_acceptance_rate"].str.extract(" (\d+) ").astype(float)
df_seattle["price"]=df_seattle["price"].str.extract("(\d+\.\d+)").astype(float)

R = df_seattle["host_acceptance_rate"].isnull()
df_seattle.loc[R,"host_acceptance_rate"] = 100

R = df_seattle["host_is_superhost"].isnull()
df_seattle.loc[R,"host_is_superhost"] =  'f'


R = df_seattle["host_has_profile_pic"].isnull()
df_seattle.loc[R,"host_has_profile_pic"] =  'f'

R = df_seattle["host_identity_verified"].isnull()
df_seattle.loc[R,"host_identity_verified"] ='f'
df_seattle.loc[:, ["host_is_superhost","host_has_profile_pic","host_identity_verified"]] = df_seattle.loc[:,["host_is_superhost","host_has_profile_pic","host_identity_verified"]].replace({"f":0,"t": 1})

response_dict = { 'within an hour': 1,'within a few hours': 2, 'within a day': 3,'a few days or more': 4}

df_seattle.loc[:,"host_response_time"] = df_seattle.loc[:,"host_response_time"].replace(response_dict)
R = df_seattle["property_type"].isnull()
df_seattle.loc[R,"property_type"] = "other"

R=df_seattle["review_scores_rating"].isnull()
df_seattle.loc[R, "review_scores_rating"] = 0

# %%
R = (df_seattle['bathrooms'].isnull()) | (df_seattle['bedrooms'].isnull()) | (df_seattle['beds'].isnull())
df_seattle = df_seattle[~R]

# %%
df_seattle.isnull().sum()
# Out:
# host_response_time        0
# host_acceptance_rate      0
# host_is_superhost         0
# host_has_profile_pic      0
# host_identity_verified    0
# neighbourhood_cleansed    0
# property_type             0
# room_type                 0
# accommodates              0
# bathrooms                 0
# bedrooms                  0
# beds                      0
# price                     0
# number_of_reviews         0
# review_scores_rating      0
# dtype: int64

# %%
df_seattle.sample(5)
# Out:
#       host_response_time  host_acceptance_rate  host_is_superhost  \
# 1232                   1                 100.0                  0
# 936                    1                 100.0                  0
# 278                    1                 100.0                  0
# 2620                   1                 100.0                  0
# 3741                   1                 100.0                  0
#
#       host_has_profile_pic  host_identity_verified neighbourhood_cleansed  \
# 1232                     1                       1               Belltown
# 936                      1                       1                  Minor
# 278                      1                       1        East Queen Anne
# 2620                     1                       1               Broadway
# 3741                     1                       1                Fremont
#
#      property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# ...

# %%
df_seattle = pd.get_dummies(df_seattle, columns=["neighbourhood_cleansed","property_type","room_type"])
df_seattle
# Out:
#       host_response_time  host_acceptance_rate  host_is_superhost  \
# 0                      2                 100.0                  0
# 1                      1                 100.0                  1
# 2                      2                 100.0                  0
# 3                      1                 100.0                  0
# 4                      1                 100.0                  0
# ...                  ...                   ...                ...
# 3813                   2                 100.0                  0
# 3814                   1                 100.0                  0
# 3815                   1                 100.0                  0
# 3816                   1                 100.0                  0
# 3817                   3                 100.0                  0
#
#       host_has_profile_pic  host_identity_verified  accommodates  bathrooms  \
# 0                        1                       1             4        1.0
# ...

# %%
from sklearn.model_selection import train_test_split

x = df_seattle.drop("price", axis=1)

y = df_seattle["price"]

x_train, x_test, y_train,y_test = train_test_split(x, y, test_size=0.2, random_state = 42)

# %%
from sklearn.svm import SVR

reg = SVR(kernel="linear")
reg.fit(x_train, y_train)
# Out:
# SVR(kernel='linear')

# %%
reg.score(x_train,y_train)
# Out:
# 0.535671745575588

# %%
reg.score(x_test,y_test)
# Out:
# 0.554511574016254
